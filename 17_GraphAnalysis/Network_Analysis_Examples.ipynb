# %% [markdown]
# Examples of Real Network Analysis
# =========================================
#
# 1. Mail Analysis
# 2. Citation Network Analysis
# 3. Twitter Network Analysis
# 4. Facebook Network Analysis

# %% [markdown]
# 1. Mail Analysis
# ==================
#
# You can find an interessting example here [Immersion: a people-centric view of your email life](https://immersion.media.mit.edu).

# %% [markdown]
# 2. Citation Network Analysis
# ===============================
#
# Some research for the [Canadian Legal Information Institute](https://www.canlii.org/en/) to help them decide how to expand the coverage of their databases of Canadian court decisions has been developed and presented in a [Notebook](http://nbviewer.ipython.org/github/twneale/citation-network-analysis/blob/master/Citation%20Network%20Analysis.ipynb).
#
# Some source of this notebook and the sample data it requires are on [github page](https://github.com/twneale/citation-network-analysis). To install locally, do the following:
#
#     $ virtualenv pydata2013
#     $ source ./pydata2013/bin/activate
#     $ git clone git@github.com:twneale/citation-network-analysis.git
#     $ cd citation-network-analysis
#     # Note: if the follwing step fails, you're missing dependencies. If resolving them is not you're cup of tea,
#     # I recommend installing the free anaconda distribution of python from Continuum Analytics: https://store.continuum.io/
#     $ pip install -r requirements.txt

# %% [markdown]
# Citation data
# -------------------------
#
# Let's load a graph containing about 6000 citations between Supreme Court of Canada (SCC) cases from the years 2000 through 2013, using JSON format.

# %%
# %matplotlib inline 
import networkx as nx

# %%
# Networks can be serialized to, and loaded from, JSON and a number of other formats.
# Here we're loading a graph
import json
from pprint import pprint
import matplotlib.pyplot as plt

json_data=open('files/scc.json')

data = json.load(json_data)
pprint(data)

# It is necessary to close the json file
json_data.close()
# Out:
# {'directed': True,
#  'graph': [],
#  'links': [{'source': 29, 'target': 3996, 'year': 2000},
#            {'source': 30, 'target': 3857, 'year': 2000},
#            {'source': 30, 'target': 1019, 'year': 2000},
#            {'source': 30, 'target': 1020, 'year': 2000},
#            {'source': 30, 'target': 1021, 'year': 2000},
#            {'source': 30, 'target': 1719, 'year': 2000},
#            {'source': 30, 'target': 803, 'year': 2000},
#            {'source': 30, 'target': 805, 'year': 2000},
#            {'source': 30, 'target': 806, 'year': 2000},
#            {'source': 30, 'target': 809, 'year': 2000},
#            {'source': 30, 'target': 810, 'year': 2000},
#            {'source': 30, 'target': 921, 'year': 2000},
#            {'source': 31, 'target': 3811, 'year': 2000},
#            {'source': 32, 'target': 3812, 'year': 2000},
#            {'source': 33, 'target': 1850, 'year': 2000},
#            {'source': 33, 'target': 35, 'year': 2000},
#            {'source': 33, 'target': 36, 'year': 2000},
#            {'source': 33, 'target': 3813, 'year': 2000},
#            {'source': 33, 'target': 3814, 'year': 2000},
#            {'source': 33, 'target': 3998, 'year': 2000},
#            {'source': 34, 'target': 3997, 'year': 2000},
#            {'source': 35, 'target': 33, 'year': 2000},
#            {'source': 35, 'target': 36, 'year': 2000},
#            {'source': 35, 'target': 3813, 'year': 2000},
#            {'source': 35, 'target': 3814, 'year': 2000},
#            {'source': 35, 'target': 3998, 'year': 2000},
#            {'source': 36, 'target': 33, 'year': 2000},
#            {'source': 36, 'target': 35, 'year': 2000},
#            {'source': 36, 'target': 3813, 'year': 2000},
#            {'source': 36, 'target': 3814, 'year': 2000},
#            {'source': 36, 'target': 3998, 'year': 2000},
#            {'source': 37, 'target': 38, 'year': 2000},
#            {'source': 37, 'target': 3815, 'year': 2000},
#            {'source': 37, 'target': 4072, 'year': 2000},
#            {'source': 37, 'target': 4142, 'year': 2000},
#            {'source': 37, 'target': 3816, 'year': 2000},
#            {'source': 38, 'target': 37, 'year': 2000},
#            {'source': 38, 'target': 3815, 'year': 2000},
#            {'source': 38, 'target': 3816, 'year': 2000},
#            {'source': 38, 'target': 4142, 'year': 2000},
#            {'source': 38, 'target': 4072, 'year': 2000},
#            {'source': 70, 'target': 4222, 'year': 2013},
#            {'source': 70, 'target': 38, 'year': 2013},
#            {'source': 70, 'target': 3816, 'year': 2013},
#            {'source': 70, 'target': 4183, 'year': 2013},
#            {'source': 70, 'target': 1453, 'year': 2013},
#            {'source': 92, 'target': 3257, 'year': 2004},
#            {'source': 92, 'target': 843, 'year': 2004},
#            {'source': 92, 'target': 2226, 'year': 2004},
#            {'source': 112, 'target': 1297, 'year': 2005},
#            {'source': 112, 'target': 149, 'year': 2005},
#            {'source': 112, 'target': 1559, 'year': 2005},
#            {'source': 112, 'target': 3695, 'year': 2005},
#            {'source': 112, 'target': 2582, 'year': 2005},
#            {'source': 113, 'target': 2823, 'year': 2003},
#            {'source': 113, 'target': 2519, 'year': 2003},
#            {'source': 113, 'target': 3593, 'year': 2003},
#            {'source': 118, 'target': 2691, 'year': 2001},
#            {'source': 118, 'target': 4282, 'year': 2001},
#            {'source': 118, 'target': 4372, 'year': 2001},
#            {'source': 119, 'target': 2693, 'year': 2001},
#            {'source': 119, 'target': 120, 'year': 2001},
#            {'source': 119, 'target': 2692, 'year': 2001},
#            {'source': 119, 'target': 3667, 'year': 2001},
#            {'source': 119, 'target': 2554, 'year': 2001},
#            {'source': 119, 'target': 2053, 'year': 2001},
#            {'source': 119, 'target': 2054, 'year': 2001},
#            {'source': 119, 'target': 1862, 'year': 2001},
#            {'source': 119, 'target': 1300, 'year': 2001},
#            {'source': 120, 'target': 2554, 'year': 2001},
#            {'source': 120, 'target': 1862, 'year': 2001},
#            {'source': 120, 'target': 2692, 'year': 2001},
#            {'source': 120, 'target': 2693, 'year': 2001},
#            {'source': 120, 'target': 119, 'year': 2001},
#            {'source': 120, 'target': 2053, 'year': 2001},
#            {'source': 120, 'target': 2054, 'year': 2001},
#            {'source': 131, 'target': 2250, 'year': 2007},
#            {'source': 131, 'target': 2258, 'year': 2007},
#            {'source': 131, 'target': 3521, 'year': 2007},
#            {'source': 131, 'target': 1283, 'year': 2007},
#            {'source': 131, 'target': 2132, 'year': 2007},
#            {'source': 131, 'target': 4712, 'year': 2007},
#            {'source': 131, 'target': 4733, 'year': 2007},
#            {'source': 131, 'target': 2550, 'year': 2007},
#            {'source': 131, 'target': 3445, 'year': 2007},
#            {'source': 131, 'target': 2553, 'year': 2007},
#            {'source': 131, 'target': 1026, 'year': 2007},
#            {'source': 131, 'target': 2413, 'year': 2007},
#            {'source': 131, 'target': 4483, 'year': 2007},
#            {'source': 131, 'target': 3129, 'year': 2007},
#            {'source': 131, 'target': 1668, 'year': 2007},
#            {'source': 131, 'target': 4756, 'year': 2007},
#            {'source': 131, 'target': 1677, 'year': 2007},
#            {'source': 131, 'target': 650, 'year': 2007},
#            {'source': 131, 'target': 2024, 'year': 2007},
#            {'source': 131, 'target': 1184, 'year': 2007},
#            {'source': 131, 'target': 1071, 'year': 2007},
#            {'source': 131, 'target': 657, 'year': 2007},
#            {'source': 131, 'target': 1227, 'year': 2007},
#            {'source': 132, 'target': 2251, 'year': 2007},
#            {'source': 132, 'target': 2480, 'year': 2007},
#            {'source': 132, 'target': 1946, 'year': 2007},
#            {'source': 132, 'target': 2550, 'year': 2007},
#            {'source': 132, 'target': 3445, 'year': 2007},
#            {'source': 132, 'target': 1026, 'year': 2007},
#            {'source': 132, 'target': 4483, 'year': 2007},
#            {'source': 132, 'target': 4756, 'year': 2007},
#            {'source': 132, 'target': 2683, 'year': 2007},
#            {'source': 132, 'target': 2468, 'year': 2007},
#            {'source': 132, 'target': 1790, 'year': 2007},
#            {'source': 132, 'target': 4149, 'year': 2007},
#            {'source': 132, 'target': 650, 'year': 2007},
#            {'source': 132, 'target': 4035, 'year': 2007},
#            {'source': 132, 'target': 2143, 'year': 2007},
#            {'source': 132, 'target': 2024, 'year': 2007},
#            {'source': 132, 'target': 1184, 'year': 2007},
#            {'source': 132, 'target': 711, 'year': 2007},
#            {'source': 132, 'target': 4071, 'year': 2007},
#            {'source': 133, 'target': 2252, 'year': 2007},
#            {'source': 134, 'target': 149, 'year': 2007},
#            {'source': 134, 'target': 2199, 'year': 2007},
#            {'source': 134, 'target': 2582, 'year': 2007},
#            {'source': 134, 'target': 2677, 'year': 2007},
#            {'source': 134, 'target': 2254, 'year': 2007},
#            {'source': 134, 'target': 241, 'year': 2007},
#            {'source': 134, 'target': 2532, 'year': 2007},
#            {'source': 134, 'target': 2826, 'year': 2007},
#            {'source': 134, 'target': 2971, 'year': 2007},
#            {'source': 135, 'target': 2255, 'year': 2007},
#            {'source': 135, 'target': 2382, 'year': 2007},
#            {'source': 135, 'target': 4278, 'year': 2007},
#            {'source': 136, 'target': 3153, 'year': 2007},
#            {'source': 136, 'target': 2256, 'year': 2007},
#            {'source': 136, 'target': 1894, 'year': 2007},
#            {'source': 136, 'target': 3339, 'year': 2007},
#            {'source': 136, 'target': 2822, 'year': 2007},
#            {'source': 136, 'target': 3741, 'year': 2007},
#            {'source': 136, 'target': 2355, 'year': 2007},
#            {'source': 138, 'target': 2253, 'year': 2007},
#            {'source': 138, 'target': 4120, 'year': 2007},
#            {'source': 138, 'target': 904, 'year': 2007},
#            {'source': 139, 'target': 3641, 'year': 2007},
#            {'source': 196, 'target': 1390, 'year': 2010},
#            {'source': 196, 'target': 2445, 'year': 2010},
#            {'source': 196, 'target': 1651, 'year': 2010},
#            {'source': 196, 'target': 546, 'year': 2010},
#            {'source': 196, 'target': 4664, 'year': 2010},
#            {'source': 196, 'target': 4666, 'year': 2010},
#            {'source': 196, 'target': 1093, 'year': 2010},
#            {'source': 196, 'target': 3076, 'year': 2010},
#            {'source': 196, 'target': 3575, 'year': 2010},
#            {'source': 196, 'target': 1371, 'year': 2010},
#            {'source': 196, 'target': 2166, 'year': 2010},
#            {'source': 196, 'target': 152, 'year': 2010},
#            {'source': 196, 'target': 3598, 'year': 2010},
#            {'source': 196, 'target': 4381, 'year': 2010},
#            {'source': 196, 'target': 4387, 'year': 2010},
#            {'source': 196, 'target': 787, 'year': 2010},
#            {'source': 196, 'target': 2614, 'year': 2010},
#            {'source': 197, 'target': 2443, 'year': 2010},
#            {'source': 197, 'target': 2582, 'year': 2010},
#            {'source': 197, 'target': 2446, 'year': 2010},
#            {'source': 197, 'target': 1651, 'year': 2010},
#            {'source': 197, 'target': 546, 'year': 2010},
#            {'source': 197, 'target': 1198, 'year': 2010},
#            {'source': 197, 'target': 2551, 'year': 2010},
#            {'source': 197, 'target': 4664, 'year': 2010},
#            {'source': 197, 'target': 1468, 'year': 2010},
#            {'source': 197, 'target': 1025, 'year': 2010},
#            {'source': 197, 'target': 3089, 'year': 2010},
#            {'source': 197, 'target': 3311, 'year': 2010},
#            {'source': 197, 'target': 651, 'year': 2010},
#            {'source': 197, 'target': 149, 'year': 2010},
#            {'source': 197, 'target': 3331, 'year': 2010},
#            {'source': 197, 'target': 56, 'year': 2010},
#            {'source': 197, 'target': 4387, 'year': 2010},
#            {'source': 198, 'target': 4674, 'year': 2010},
#            {'source': 198, 'target': 4586, 'year': 2010},
#            {'source': 198, 'target': 4669, 'year': 2010},
#            {'source': 198, 'target': 1232, 'year': 2010},
#            {'source': 198, 'target': 4384, 'year': 2010},
#            {'source': 198, 'target': 2203, 'year': 2010},
#            {'source': 198, 'target': 2440, 'year': 2010},
#            {'source': 198, 'target': 3392, 'year': 2010},
#            {'source': 198, 'target': 4775, 'year': 2010},
#            {'source': 198, 'target': 1938, 'year': 2010},
#            {'source': 198, 'target': 3797, 'year': 2010},
#            {'source': 198, 'target': 1196, 'year': 2010},
#            {'source': 198, 'target': 2345, 'year': 2010},
#            {'source': 198, 'target': 3309, 'year': 2010},
#            {'source': 198, 'target': 328, 'year': 2010},
#            {'source': 198, 'target': 3576, 'year': 2010},
#            {'source': 198, 'target': 2969, 'year': 2010},
#            {'source': 199, 'target': 2441, 'year': 2010},
#            {'source': 199, 'target': 2289, 'year': 2010},
#            {'source': 199, 'target': 3338, 'year': 2010},
#            {'source': 199, 'target': 4144, 'year': 2010},
#            {'source': 199, 'target': 4074, 'year': 2010},
#            {'source': 200, 'target': 2442, 'year': 2010},
#            {'source': 200, 'target': 4301, 'year': 2010},
#            {'source': 200, 'target': 1123, 'year': 2010},
#            {'source': 200, 'target': 1896, 'year': 2010},
#            {'source': 200, 'target': 2470, 'year': 2010},
#            {'source': 200, 'target': 1406, 'year': 2010},
#            {'source': 200, 'target': 3336, 'year': 2010},
#            {'source': 200, 'target': 3338, 'year': 2010},
#            {'source': 200, 'target': 1939, 'year': 2010},
#            {'source': 200, 'target': 2289, 'year': 2010},
#            {'source': 200, 'target': 3563, 'year': 2010},
#            {'source': 200, 'target': 2547, 'year': 2010},
#            {'source': 200, 'target': 4214, 'year': 2010},
#            {'source': 200, 'target': 487, 'year': 2010},
#            {'source': 200, 'target': 861, 'year': 2010},
#            {'source': 200, 'target': 1906, 'year': 2010},
#            {'source': 200, 'target': 2989, 'year': 2010},
#            {'source': 200, 'target': 797, 'year': 2010},
#            {'source': 200, 'target': 1172, 'year': 2010},
#            {'source': 200, 'target': 2057, 'year': 2010},
#            {'source': 200, 'target': 150, 'year': 2010},
#            {'source': 200, 'target': 1996, 'year': 2010},
#            {'source': 200, 'target': 1429, 'year': 2010},
#            {'source': 200, 'target': 654, 'year': 2010},
#            {'source': 200, 'target': 587, 'year': 2010},
#            {'source': 200, 'target': 4499, 'year': 2010},
#            {'source': 200, 'target': 1393, 'year': 2010},
#            {'source': 200, 'target': 1132, 'year': 2010},
#            {'source': 200, 'target': 3565, 'year': 2010},
#            {'source': 200, 'target': 2384, 'year': 2010},
#            {'source': 200, 'target': 53, 'year': 2010},
#            {'source': 201, 'target': 2266, 'year': 2010},
#            {'source': 201, 'target': 4782, 'year': 2010},
#            {'source': 201, 'target': 2448, 'year': 2010},
#            {'source': 201, 'target': 2449, 'year': 2010},
#            {'source': 201, 'target': 202, 'year': 2010},
#            {'source': 202, 'target': 1892, 'year': 2010},
#            {'source': 202, 'target': 2449, 'year': 2010},
#            {'source': 202, 'target': 1285, 'year': 2010},
#            {'source': 202, 'target': 1071, 'year': 2010},
#            {'source': 202, 'target': 2132, 'year': 2010},
#            {'source': 202, 'target': 34, 'year': 2010},
#            {'source': 202, 'target': 3997, 'year': 2010},
#            {'source': 202, 'target': 3746, 'year': 2010},
#            {'source': 202, 'target': 3130, 'year': 2010},
#            {'source': 241, 'target': 1893, 'year': 2007},
#            {'source': 241, 'target': 3518, 'year': 2007},
#            {'source': 241, 'target': 2762, 'year': 2007},
#            {'source': 241, 'target': 3799, 'year': 2007},
#            {'source': 241, 'target': 2828, 'year': 2007},
#            {'source': 241, 'target': 1671, 'year': 2007},
#            {'source': 241, 'target': 3747, 'year': 2007},
#            {'source': 241, 'target': 1461, 'year': 2007},
#            {'source': 241, 'target': 2532, 'year': 2007},
#            {'source': 241, 'target': 149, 'year': 2007},
#            {'source': 241, 'target': 2582, 'year': 2007},
#            {'source': 277, 'target': 3620, 'year': 2001},
#            {'source': 315, 'target': 1790, 'year': 2009},
#            {'source': 315, 'target': 1139, 'year': 2009},
#            {'source': 315, 'target': 2645, 'year': 2009},
#            {'source': 315, 'target': 1291, 'year': 2009},
#            {'source': 315, 'target': 2076, 'year': 2009},
#            {'source': 315, 'target': 856, 'year': 2009},
#            {'source': 315, 'target': 4191, 'year': 2009},
#            {'source': 315, 'target': 2257, 'year': 2009},
#            {'source': 315, 'target': 2683, 'year': 2009},
#            {'source': 315, 'target': 4583, 'year': 2009},
#            {'source': 315, 'target': 4575, 'year': 2009},
#            {'source': 315, 'target': 3834, 'year': 2009},
#            {'source': 315, 'target': 1674, 'year': 2009},
#            {'source': 315, 'target': 1675, 'year': 2009},
#            {'source': 315, 'target': 45, 'year': 2009},
#            {'source': 315, 'target': 623, 'year': 2009},
#            {'source': 315, 'target': 1281, 'year': 2009},
#            {'source': 315, 'target': 2346, 'year': 2009},
#            {'source': 315, 'target': 4051, 'year': 2009},
#            {'source': 316, 'target': 3938, 'year': 2009},
#            {'source': 317, 'target': 3940, 'year': 2009},
#            {'source': 318, 'target': 3935, 'year': 2009},
#            {'source': 318, 'target': 3593, 'year': 2009},
#            {'source': 318, 'target': 2519, 'year': 2009},
#            {'source': 319, 'target': 1969, 'year': 2009},
#            {'source': 319, 'target': 1390, 'year': 2009},
#            {'source': 319, 'target': 1292, 'year': 2009},
#            {'source': 319, 'target': 512, 'year': 2009},
#            {'source': 319, 'target': 3076, 'year': 2009},
#            {'source': 319, 'target': 1371, 'year': 2009},
#            {'source': 319, 'target': 152, 'year': 2009},
#            {'source': 319, 'target': 3936, 'year': 2009},
#            {'source': 319, 'target': 3598, 'year': 2009},
#            {'source': 319, 'target': 624, 'year': 2009},
#            {'source': 319, 'target': 2614, 'year': 2009},
#            {'source': 320, 'target': 4582, 'year': 2009},
#            {'source': 321, 'target': 3941, 'year': 2009},
#            {'source': 322, 'target': 391, 'year': 2009},
#            {'source': 322, 'target': 2550, 'year': 2009},
#            {'source': 322, 'target': 100, 'year': 2009},
#            {'source': 322, 'target': 4373, 'year': 2009},
#            {'source': 322, 'target': 759, 'year': 2009},
#            {'source': 322, 'target': 760, 'year': 2009},
#            {'source': 322, 'target': 2011, 'year': 2009},
#            {'source': 322, 'target': 1817, 'year': 2009},
#            {'source': 322, 'target': 650, 'year': 2009},
#            {'source': 322, 'target': 2012, 'year': 2009},
#            {'source': 322, 'target': 3942, 'year': 2009},
#            {'source': 352, 'target': 3879, 'year': 2001},
#            {'source': 352, 'target': 4277, 'year': 2001},
#            {'source': 352, 'target': 3789, 'year': 2001},
#            {'source': 353, 'target': 174, 'year': 2001},
#            {'source': 353, 'target': 3140, 'year': 2001},
#            {'source': 353, 'target': 559, 'year': 2001},
#            {'source': 354, 'target': 3670, 'year': 2001},
#            {'source': 354, 'target': 3671, 'year': 2001},
#            {'source': 354, 'target': 3144, 'year': 2001},
#            {'source': 354, 'target': 4514, 'year': 2001},
#            {'source': 354, 'target': 4515, 'year': 2001},
#            {'source': 355, 'target': 33, 'year': 2001},
#            {'source': 355, 'target': 3813, 'year': 2001},
#            {'source': 355, 'target': 3588, 'year': 2001},
#            {'source': 355, 'target': 2354, 'year': 2001},
#            {'source': 355, 'target': 4068, 'year': 2001},
#            {'source': 356, 'target': 2083, 'year': 2001},
#            {'source': 357, 'target': 3137, 'year': 2001},
#            {'source': 358, 'target': 3138, 'year': 2001},
#            {'source': 374, 'target': 1084, 'year': 2005},
#            {'source': 379, 'target': 796, 'year': 2001},
#            {'source': 379, 'target': 338, 'year': 2001},
#            {'source': 379, 'target': 1815, 'year': 2001},
#            {'source': 389, 'target': 1018, 'year': 2004},
#            {'source': 389, 'target': 808, 'year': 2004},
#            {'source': 389, 'target': 642, 'year': 2004},
#            {'source': 390, 'target': 99, 'year': 2004},
#            {'source': 391, 'target': 100, 'year': 2004},
#            {'source': 391, 'target': 3887, 'year': 2004},
#            {'source': 391, 'target': 3464, 'year': 2004},
#            {'source': 417, 'target': 3552, 'year': 2010},
#            {'source': 418, 'target': 2446, 'year': 2010},
#            {'source': 418, 'target': 993, 'year': 2010},
#            {'source': 418, 'target': 197, 'year': 2010},
#            {'source': 418, 'target': 3553, 'year': 2010},
#            {'source': 418, 'target': 856, 'year': 2010},
#            {'source': 418, 'target': 4575, 'year': 2010},
#            {'source': 418, 'target': 156, 'year': 2010},
#            {'source': 418, 'target': 1812, 'year': 2010},
#            {'source': 418, 'target': 3602, 'year': 2010},
#            {'source': 419, 'target': 99, 'year': 2010},
#            {'source': 419, 'target': 33, 'year': 2010},
#            {'source': 419, 'target': 3813, 'year': 2010},
#            {'source': 419, 'target': 390, 'year': 2010},
#            {'source': 419, 'target': 3554, 'year': 2010},
#            {'source': 420, 'target': 1121, 'year': 2010},
#            {'source': 420, 'target': 1545, 'year': 2010},
#            {'source': 420, 'target': 4270, 'year': 2010},
#            {'source': 420, 'target': 830, 'year': 2010},
#            {'source': 420, 'target': 999, 'year': 2010},
#            {'source': 420, 'target': 2763, 'year': 2010},
#            {'source': 420, 'target': 2328, 'year': 2010},
#            {'source': 420, 'target': 315, 'year': 2010},
#            {'source': 420, 'target': 174, 'year': 2010},
#            {'source': 420, 'target': 2829, 'year': 2010},
#            {'source': 420, 'target': 2830, 'year': 2010},
#            {'source': 420, 'target': 911, 'year': 2010},
#            {'source': 420, 'target': 559, 'year': 2010},
#            {'source': 420, 'target': 1792, 'year': 2010},
#            {'source': 420, 'target': 2077, 'year': 2010},
#            {'source': 420, 'target': 2657, 'year': 2010},
#            {'source': 420, 'target': 3894, 'year': 2010},
#            {'source': 420, 'target': 1909, 'year': 2010},
#            {'source': 420, 'target': 548, 'year': 2010},
#            {'source': 420, 'target': 3834, 'year': 2010},
#            {'source': 420, 'target': 1139, 'year': 2010},
#            {'source': 420, 'target': 2140, 'year': 2010},
#            {'source': 420, 'target': 4583, 'year': 2010},
#            {'source': 420, 'target': 489, 'year': 2010},
#            {'source': 420, 'target': 4056, 'year': 2010},
#            {'source': 420, 'target': 4312, 'year': 2010},
#            {'source': 420, 'target': 3780, 'year': 2010},
#            {'source': 421, 'target': 3555, 'year': 2010},
#            {'source': 422, 'target': 1390, 'year': 2010},
#            {'source': 422, 'target': 2445, 'year': 2010},
#            {'source': 422, 'target': 3798, 'year': 2010},
#            {'source': 422, 'target': 258, 'year': 2010},
#            {'source': 422, 'target': 1292, 'year': 2010},
#            {'source': 422, 'target': 4034, 'year': 2010},
#            {'source': 422, 'target': 3076, 'year': 2010},
#            {'source': 422, 'target': 319, 'year': 2010},
#            {'source': 422, 'target': 1460, 'year': 2010},
#            {'source': 422, 'target': 196, 'year': 2010},
#            {'source': 422, 'target': 624, 'year': 2010},
#            {'source': 422, 'target': 3575, 'year': 2010},
#            {'source': 422, 'target': 3556, 'year': 2010},
#            {'source': 422, 'target': 1371, 'year': 2010},
#            {'source': 422, 'target': 3936, 'year': 2010},
#            {'source': 422, 'target': 152, 'year': 2010},
#            {'source': 422, 'target': 3598, 'year': 2010},
#            {'source': 422, 'target': 1683, 'year': 2010},
#            {'source': 422, 'target': 2879, 'year': 2010},
#            {'source': 422, 'target': 2166, 'year': 2010},
#            {'source': 422, 'target': 2614, 'year': 2010},
#            {'source': 423, 'target': 2897, 'year': 2010},
#            {'source': 423, 'target': 3557, 'year': 2010},
#            {'source': 423, 'target': 698, 'year': 2010},
#            {'source': 423, 'target': 1792, 'year': 2010},
#            {'source': 423, 'target': 1193, 'year': 2010},
#            {'source': 423, 'target': 1460, 'year': 2010},
#            {'source': 423, 'target': 756, 'year': 2010},
#            {'source': 423, 'target': 1940, 'year': 2010},
#            {'source': 423, 'target': 3798, 'year': 2010},
#            {'source': 423, 'target': 4373, 'year': 2010},
#            {'source': 423, 'target': 895, 'year': 2010},
#            {'source': 423, 'target': 271, 'year': 2010},
#            {'source': 423, 'target': 1817, 'year': 2010},
#            {'source': 423, 'target': 358, 'year': 2010},
#            {'source': 423, 'target': 4270, 'year': 2010},
#            {'source': 423, 'target': 4327, 'year': 2010},
#            {'source': 423, 'target': 3929, 'year': 2010},
#            {'source': 423, 'target': 3138, 'year': 2010},
#            {'source': 423, 'target': 1685, 'year': 2010},
#            {'source': 423, 'target': 2554, 'year': 2010},
#            {'source': 423, 'target': 3201, 'year': 2010},
#            {'source': 423, 'target': 3332, 'year': 2010},
#            {'source': 423, 'target': 4429, 'year': 2010},
#            {'source': 423, 'target': 2053, 'year': 2010},
#            {'source': 423, 'target': 2016, 'year': 2010},
#            {'source': 424, 'target': 3557, 'year': 2010},
#            {'source': 424, 'target': 423, 'year': 2010},
#            {'source': 424, 'target': 3558, 'year': 2010},
#            {'source': 425, 'target': 704, 'year': 2010},
#            {'source': 425, 'target': 2482, 'year': 2010},
#            {'source': 425, 'target': 2756, 'year': 2010},
#            {'source': 425, 'target': 1673, 'year': 2010},
#            {'source': 425, 'target': 3559, 'year': 2010},
#            {'source': 425, 'target': 3520, 'year': 2010},
#            {'source': 425, 'target': 2137, 'year': 2010},
#            {'source': 426, 'target': 3560, 'year': 2010},
#            {'source': 454, 'target': 1555, 'year': 2008},
#            {'source': 455, 'target': 1557, 'year': 2008},
#            {'source': 456, 'target': 171, 'year': 2008},
#            {'source': 456, 'target': 427, 'year': 2008},
#            {'source': 456, 'target': 172, 'year': 2008},
#            {'source': 456, 'target': 3172, 'year': 2008},
#            {'source': 456, 'target': 3173, 'year': 2008},
#            {'source': 456, 'target': 2518, 'year': 2008},
#            {'source': 456, 'target': 2164, 'year': 2008},
#            {'source': 465, 'target': 2647, 'year': 2004},
#            {'source': 466, 'target': 2642, 'year': 2004},
#            {'source': 466, 'target': 4043, 'year': 2004},
#            {'source': 466, 'target': 1704, 'year': 2004},
#            {'source': 467, 'target': 4371, 'year': 2004},
#            {'source': 467, 'target': 2644, 'year': 2004},
#            {'source': 467, 'target': 3427, 'year': 2004},
#            {'source': 557, 'target': 165, 'year': 2000},
#            {'source': 558, 'target': 166, 'year': 2000},
#            {'source': 559, 'target': 174, 'year': 2000},
#            {'source': 559, 'target': 4369, 'year': 2000},
#            {'source': 559, 'target': 2136, 'year': 2000},
#            {'source': 559, 'target': 4279, 'year': 2000},
#            {'source': 559, 'target': 4067, 'year': 2000},
#            {'source': 580, 'target': 997, 'year': 2007},
#            {'source': 580, 'target': 3294, 'year': 2007},
#            {'source': 580, 'target': 4039, 'year': 2007},
#            {'source': 580, 'target': 3385, 'year': 2007},
#            {'source': 580, 'target': 1230, 'year': 2007},
#            {'source': 580, 'target': 4548, 'year': 2007},
#            {'source': 580, 'target': 1780, 'year': 2007},
#            {'source': 581, 'target': 4266, 'year': 2007},
#            {'source': 581, 'target': 2785, 'year': 2007},
#            {'source': 581, 'target': 4033, 'year': 2007},
#            {'source': 581, 'target': 4549, 'year': 2007},
#            {'source': 581, 'target': 1781, 'year': 2007},
#            {'source': 582, 'target': 3389, 'year': 2007},
#            {'source': 582, 'target': 4002, 'year': 2007},
#            {'source': 582, 'target': 1782, 'year': 2007},
#            {'source': 583, 'target': 4481, 'year': 2007},
#            {'source': 583, 'target': 4038, 'year': 2007},
#            {'source': 583, 'target': 2351, 'year': 2007},
#            {'source': 583, 'target': 705, 'year': 2007},
#            {'source': 583, 'target': 47, 'year': 2007},
#            {'source': 583, 'target': 2771, 'year': 2007},
#            {'source': 583, 'target': 1404, 'year': 2007},
#            {'source': 584, 'target': 787, 'year': 2007},
#            {'source': 584, 'target': 1288, 'year': 2007},
#            {'source': 584, 'target': 960, 'year': 2007},
#            {'source': 584, 'target': 263, 'year': 2007},
#            {'source': 584, 'target': 4373, 'year': 2007},
#            {'source': 584, 'target': 1093, 'year': 2007},
#            {'source': 584, 'target': 2411, 'year': 2007},
#            {'source': 584, 'target': 1817, 'year': 2007},
#            {'source': 584, 'target': 3203, 'year': 2007},
#            {'source': 584, 'target': 1784, 'year': 2007},
#            {'source': 584, 'target': 1682, 'year': 2007},
#            {'source': 585, 'target': 1785, 'year': 2007},
#            {'source': 586, 'target': 353, 'year': 2007},
#            {'source': 586, 'target': 3140, 'year': 2007},
#            {'source': 586, 'target': 1405, 'year': 2007},
#            {'source': 587, 'target': 1894, 'year': 2007},
#            {'source': 587, 'target': 1394, 'year': 2007},
#            {'source': 587, 'target': 1149, 'year': 2007},
#            {'source': 587, 'target': 3741, 'year': 2007},
#            {'source': 587, 'target': 1906, 'year': 2007},
#            {'source': 587, 'target': 1996, 'year': 2007},
#            {'source': 587, 'target': 797, 'year': 2007},
#            {'source': 587, 'target': 2969, 'year': 2007},
#            {'source': 587, 'target': 487, 'year': 2007},
#            {'source': 587, 'target': 4366, 'year': 2007},
#            {'source': 587, 'target': 2203, 'year': 2007},
#            {'source': 587, 'target': 3029, 'year': 2007},
#            {'source': 587, 'target': 1406, 'year': 2007},
#            {'source': 590, 'target': 4299, 'year': 2009},
#            {'source': 590, 'target': 1972, 'year': 2009},
#            {'source': 590, 'target': 3058, 'year': 2009},
#            {'source': 590, 'target': 1002, 'year': 2009},
#            {'source': 590, 'target': 33, 'year': 2009},
#            {'source': 590, 'target': 550, 'year': 2009},
#            {'source': 590, 'target': 4611, 'year': 2009},
#            {'source': 590, 'target': 3813, 'year': 2009},
#            {'source': 590, 'target': 3077, 'year': 2009},
#            {'source': 590, 'target': 1169, 'year': 2009},
#            {'source': 590, 'target': 1433, 'year': 2009},
#            {'source': 591, 'target': 4613, 'year': 2009},
#            {'source': 591, 'target': 4614, 'year': 2009},
#            {'source': 591, 'target': 4615, 'year': 2009},
#            {'source': 591, 'target': 592, 'year': 2009},
#            {'source': 591, 'target': 593, 'year': 2009},
#            {'source': 592, 'target': 4613, 'year': 2009},
#            {'source': 592, 'target': 4614, 'year': 2009},
#            {'source': 592, 'target': 4615, 'year': 2009},
#            {'source': 592, 'target': 591, 'year': 2009},
#            {'source': 592, 'target': 593, 'year': 2009},
#            {'source': 593, 'target': 1460, 'year': 2009},
#            {'source': 593, 'target': 3798, 'year': 2009},
#            {'source': 593, 'target': 469, 'year': 2009},
#            {'source': 593, 'target': 4615, 'year': 2009},
#            {'source': 593, 'target': 448, 'year': 2009},
#            {'source': 593, 'target': 2357, 'year': 2009},
#            {'source': 593, 'target': 709, 'year': 2009},
#            {'source': 594, 'target': 3857, 'year': 2009},
#            {'source': 594, 'target': 4617, 'year': 2009},
#            {'source': 594, 'target': 1460, 'year': 2009},
#            {'source': 594, 'target': 3798, 'year': 2009},
#            {'source': 594, 'target': 803, 'year': 2009},
#            {'source': 594, 'target': 469, 'year': 2009},
#            {'source': 594, 'target': 2357, 'year': 2009},
#            {'source': 605, 'target': 2414, 'year': 2004},
#            {'source': 605, 'target': 2415, 'year': 2004},
#            {'source': 605, 'target': 3195, 'year': 2004},
#            {'source': 615, 'target': 3787, 'year': 2010},
#            {'source': 616, 'target': 3849, 'year': 2010},
#            {'source': 616, 'target': 1460, 'year': 2010},
#            {'source': 616, 'target': 3891, 'year': 2010},
#            {'source': 616, 'target': 3784, 'year': 2010},
#            {'source': 616, 'target': 3798, 'year': 2010},
#            {'source': 617, 'target': 3786, 'year': 2010},
#            {'source': 617, 'target': 3892, 'year': 2010},
#            {'source': 617, 'target': 3785, 'year': 2010},
#            {'source': 618, 'target': 3781, 'year': 2010},
#            {'source': 619, 'target': 2440, 'year': 2010},
#            {'source': 619, 'target': 3392, 'year': 2010},
#            {'source': 619, 'target': 3782, 'year': 2010},
#            {'source': 619, 'target': 3991, 'year': 2010},
#            {'source': 619, 'target': 4175, 'year': 2010},
#            {'source': 619, 'target': 1645, 'year': 2010},
#            {'source': 619, 'target': 198, 'year': 2010},
#            {'source': 619, 'target': 2656, 'year': 2010},
#            {'source': 619, 'target': 2969, 'year': 2010},
#            {'source': 619, 'target': 1232, 'year': 2010},
#            {'source': 619, 'target': 4149, 'year': 2010},
#            {'source': 619, 'target': 1691, 'year': 2010},
#            {'source': 619, 'target': 2203, 'year': 2010},
#            {'source': 619, 'target': 4311, 'year': 2010},
#            {'source': 619, 'target': 4071, 'year': 2010},
#            {'source': 620, 'target': 3935, 'year': 2010},
#            {'source': 620, 'target': 113, 'year': 2010},
#            {'source': 620, 'target': 3783, 'year': 2010},
#            {'source': 620, 'target': 318, 'year': 2010},
#            {'source': 620, 'target': 922, 'year': 2010},
#            {'source': 620, 'target': 2823, 'year': 2010},
#            {'source': 620, 'target': 1940, 'year': 2010},
#            {'source': 620, 'target': 1574, 'year': 2010},
#            {'source': 620, 'target': 1193, 'year': 2010},
#            {'source': 621, 'target': 174, 'year': 2005},
#            {'source': 621, 'target': 2822, 'year': 2005},
#            {'source': 621, 'target': 559, 'year': 2005},
#            {'source': 621, 'target': 3928, 'year': 2005},
#            {'source': 621, 'target': 2355, 'year': 2005},
#            {'source': 622, 'target': 1290, 'year': 2003},
#            {'source': 622, 'target': 3445, 'year': 2003},
#            {'source': 622, 'target': 4483, 'year': 2003},
#            {'source': 622, 'target': 4756, 'year': 2003},
#            {'source': 622, 'target': 623, 'year': 2003},
#            {'source': 622, 'target': 1291, 'year': 2003},
#            {'source': 622, 'target': 2024, 'year': 2003},
#            {'source': 623, 'target': 3445, 'year': 2003},
#            {'source': 623, 'target': 3667, 'year': 2003},
#            {'source': 623, 'target': 4266, 'year': 2003},
#            {'source': 623, 'target': 33, 'year': 2003},
#            {'source': 623, 'target': 1290, 'year': 2003},
#            {'source': 623, 'target': 1291, 'year': 2003},
#            {'source': 623, 'target': 3813, 'year': 2003},
#            {'source': 623, 'target': 4483, 'year': 2003},
#            {'source': 623, 'target': 2785, 'year': 2003},
#            {'source': 623, 'target': 151, 'year': 2003},
#            {'source': 623, 'target': 622, 'year': 2003},
#            {'source': 623, 'target': 4756, 'year': 2003},
#            {'source': 623, 'target': 2024, 'year': 2003},
#            {'source': 623, 'target': 2583, 'year': 2003},
#            {'source': 623, 'target': 1300, 'year': 2003},
#            {'source': 624, 'target': 1292, 'year': 2003},
#            {'source': 624, 'target': 2382, 'year': 2003},
#            {'source': 624, 'target': 856, 'year': 2003},
#            {'source': 624, 'target': 152, 'year': 2003},
#            {'source': 624, 'target': 2785, 'year': 2003},
#            {'source': 624, 'target': 4575, 'year': 2003},
#            {'source': 624, 'target': 3598, 'year': 2003},
#            {'source': 624, 'target': 4266, 'year': 2003},
#            {'source': 624, 'target': 4278, 'year': 2003},
#            {'source': 625, 'target': 1293, 'year': 2003},
#            {'source': 626, 'target': 3388, 'year': 2001},
#            {'source': 626, 'target': 2366, 'year': 2001},
#            {'source': 626, 'target': 2292, 'year': 2001},
#            {'source': 678, 'target': 270, 'year': 2009},
#            {'source': 678, 'target': 273, 'year': 2009},
#            {'source': 678, 'target': 1701, 'year': 2009},
#            {'source': 678, 'target': 4045, 'year': 2009},
#            {'source': 678, 'target': 926, 'year': 2009},
#            {'source': 681, 'target': 1289, 'year': 2003},
#            {'source': 682, 'target': 2894, 'year': 2003},
#            {'source': 682, 'target': 1294, 'year': 2003},
#            {'source': 682, 'target': 1688, 'year': 2003},
#            {'source': 683, 'target': 2646, 'year': 2004},
#            {'source': 705, 'target': 1892, 'year': 2006},
#            {'source': 705, 'target': 2132, 'year': 2006},
#            {'source': 705, 'target': 34, 'year': 2006},
#            {'source': 753, 'target': 3671, 'year': 2007},
#            {'source': 753, 'target': 144, 'year': 2007},
#            {'source': 753, 'target': 856, 'year': 2007},
#            {'source': 753, 'target': 4575, 'year': 2007},
#            {'source': 753, 'target': 3453, 'year': 2007},
#            {'source': 753, 'target': 1570, 'year': 2007},
#            {'source': 753, 'target': 4515, 'year': 2007},
#            {'source': 753, 'target': 1684, 'year': 2007},
#            {'source': 754, 'target': 4273, 'year': 2007},
#            {'source': 754, 'target': 4266, 'year': 2007},
#            {'source': 754, 'target': 2135, 'year': 2007},
#            {'source': 754, 'target': 2785, 'year': 2007},
#            {'source': 754, 'target': 2013, 'year': 2007},
#            {'source': 754, 'target': 1069, 'year': 2007},
#            {'source': 755, 'target': 2127, 'year': 2007},
#            {'source': 755, 'target': 3572, 'year': 2007},
#            {'source': 755, 'target': 2417, 'year': 2007},
#            {'source': 755, 'target': 856, 'year': 2007},
#            {'source': 755, 'target': 843, 'year': 2007},
#            {'source': 755, 'target': 844, 'year': 2007},
#            {'source': 755, 'target': 2226, 'year': 2007},
#            {'source': 755, 'target': 1916, 'year': 2007},
#            {'source': 755, 'target': 4575, 'year': 2007},
#            {'source': 755, 'target': 488, 'year': 2007},
#            {'source': 755, 'target': 2162, 'year': 2007},
#            {'source': 755, 'target': 3595, 'year': 2007},
#            {'source': 755, 'target': 959, 'year': 2007},
#            {'source': 755, 'target': 3739, 'year': 2007},
#            {'source': 755, 'target': 1908, 'year': 2007},
#            {'source': 755, 'target': 2014, 'year': 2007},
#            {'source': 755, 'target': 3574, 'year': 2007},
#            {'source': 755, 'target': 3579, 'year': 2007},
#            {'source': 755, 'target': 1131, 'year': 2007},
#            {'source': 756, 'target': 4270, 'year': 2007},
#            {'source': 756, 'target': 960, 'year': 2007},
#            {'source': 756, 'target': 1940, 'year': 2007},
#            {'source': 756, 'target': 2411, 'year': 2007},
#            {'source': 756, 'target': 2016, 'year': 2007},
#            {'source': 756, 'target': 1792, 'year': 2007},
#            {'source': 756, 'target': 358, 'year': 2007},
#            {'source': 756, 'target': 3138, 'year': 2007},
#            {'source': 756, 'target': 2643, 'year': 2007},
#            {'source': 756, 'target': 4050, 'year': 2007},
#            {'source': 756, 'target': 1193, 'year': 2007},
#            {'source': 757, 'target': 4305, 'year': 2007},
#            {'source': 757, 'target': 3338, 'year': 2007},
#            {'source': 757, 'target': 1445, 'year': 2007},
#            {'source': 757, 'target': 1917, 'year': 2007},
#            {'source': 757, 'target': 3110, 'year': 2007},
#            {'source': 757, 'target': 2009, 'year': 2007},
#            {'source': 757, 'target': 2289, 'year': 2007},
#            {'source': 757, 'target': 2352, 'year': 2007},
#            {'source': 757, 'target': 3617, 'year': 2007},
#            {'source': 757, 'target': 3692, 'year': 2007},
#            {'source': 757, 'target': 1168, 'year': 2007},
#            {'source': 758, 'target': 2010, 'year': 2007},
#            {'source': 759, 'target': 1445, 'year': 2007},
#            {'source': 759, 'target': 760, 'year': 2007},
#            {'source': 759, 'target': 401, 'year': 2007},
#            {'source': 759, 'target': 3617, 'year': 2007},
#            {'source': 759, 'target': 4733, 'year': 2007},
#            {'source': 788, 'target': 3746, 'year': 2005},
#            {'source': 788, 'target': 1071, 'year': 2005},
#            {'source': 788, 'target': 3833, 'year': 2005},
#            {'source': 788, 'target': 2132, 'year': 2005},
#            {'source': 788, 'target': 3140, 'year': 2005},
#            {'source': 788, 'target': 1892, 'year': 2005},
#            {'source': 788, 'target': 3798, 'year': 2005},
#            {'source': 788, 'target': 34, 'year': 2005},
#            {'source': 788, 'target': 1756, 'year': 2005},
#            {'source': 788, 'target': 3997, 'year': 2005},
#            {'source': 788, 'target': 2970, 'year': 2005},
#            {'source': 788, 'target': 2023, 'year': 2005},
#            {'source': 789, 'target': 3991, 'year': 2005},
#            {'source': 789, 'target': 1087, 'year': 2005},
#            {'source': 789, 'target': 1691, 'year': 2005},
#            {'source': 789, 'target': 1393, 'year': 2005},
#            {'source': 789, 'target': 2057, 'year': 2005},
#            {'source': 790, 'target': 3857, 'year': 2005},
#            {'source': 790, 'target': 3916, 'year': 2005},
# ...
#            {'id': '2002-sccno-56'},
#            {'id': '1999-sccano-361'},
#            {'id': '1993-sccano-30'},
#            {'id': '1996-sccano-542'},
#            {'id': '1996-sccano-541'},
#            {'id': '2006-sccno-407'},
#            {'id': '2010-sccano-527'},
#            {'id': '2011-scc-60'},
#            {'id': '1990-sccano-453'},
#            {'id': '2009-sccano-177'},
#            {'id': '2009-sccano-176'},
#            {'id': '1985-sccano-158'},
#            {'id': '2006scc54'},
#            {'id': '1999-sccano-349'},
#            {'id': '2001-scc-69'},
#            {'id': '2001-scc-68'},
#            {'id': '2010-scca-32'},
#            {'id': '2003-scca-525'},
#            {'id': '2001-scc-60'},
#            {'id': '2001scc60'},
#            {'id': '2008-sccano-102'},
#            {'id': '1997-sccano-207'},
#            {'id': '1988-sccano-370'},
#            {'id': '2008scc21'},
#            {'id': '2008scc25'},
#            {'id': '2003-scc-3'},
#            {'id': '2003-scc-5'},
#            {'id': '1995-sccano-217'},
#            {'id': '2000scc37'},
#            {'id': '2000scc35'},
#            {'id': '2000scc34'},
#            {'id': '2000scc32'},
#            {'id': '2000scc31'},
#            {'id': '2000scc30'},
#            {'id': '2008-sccano-139'},
#            {'id': '1996-sccano-54'},
#            {'id': '2000-sccano-323'},
#            {'id': '2000-sccano-322'},
#            {'id': '2000-sccano-328'},
#            {'id': '2009-scc-38'},
#            {'id': '2009-scc-34'},
#            {'id': '2009-scc-35'},
#            {'id': '2009-scc-36'},
#            {'id': '2009-scc-37'},
#            {'id': '2009-scc-30'},
#            {'id': '2009-scc-31'},
#            {'id': '2009-scc-32'},
#            {'id': '2009-scc-33'},
#            {'id': '2008-sccano-3034'},
#            {'id': '2003-sccano-419'},
#            {'id': '2002-sccano-322'},
#            {'id': '2009scc39'},
#            {'id': '45-scc2d-333'},
#            {'id': '1991-sccano-57'},
#            {'id': '1991-sccano-54'},
#            {'id': '1991-sccano-55'},
#            {'id': '1991-sccano-52'},
#            {'id': '1991-sccano-58'},
#            {'id': '2009scc3'},
#            {'id': '1999-sccano-585'},
#            {'id': '1999-sccano-588'},
#            {'id': '2003-sccano-8'},
#            {'id': '2009-sccano-248'},
#            {'id': '2009-sccano-244'},
#            {'id': '1999-sccano-238'},
#            {'id': '2008scc13'},
#            {'id': '2008scc14'},
#            {'id': '2010-sccano-212'},
#            {'id': '2010-sccano-213'},
#            {'id': '2004-sccano-246'},
#            {'id': '2004-sccano-244'},
#            {'id': '1999-sccano-147'},
#            {'id': '1988-sccano-32'},
#            {'id': '2008-sccano-522'},
#            {'id': '2002scc75'},
#            {'id': '2000-sccano-619'},
#            {'id': '2010scc36'},
#            {'id': '2010scc34'},
#            {'id': '2010scc35'},
#            {'id': '2010scc32'},
#            {'id': '2010scc33'},
#            {'id': '2010scc30'},
#            {'id': '2010scc31'},
#            {'id': '2010scc39'},
#            {'id': '1997-scca-656'},
#            {'id': '2009-sccano-450'},
#            {'id': '2009-sccano-455'},
#            {'id': '2003-sccano-95'}]}

# %%
# Build a graph from the data
import json
from networkx.readwrite import json_graph

G = json_graph.node_link_graph(data)

pos=nx.spring_layout(G)   # G is my graph, pos determines the position of nodes.

# Draw simpler graph:
nx.draw(G)

# %%
from itertools import islice

# Now we can look at some basic characteristics of the network.
print('Number of nodes:', G.number_of_nodes())
print('Number of edges:', G.number_of_edges())
 
# Let's view some of the nodes.
print('Here are a few nodes')
for node in islice(G.edges().items(), 10):
    print(' -', node)
    
# Let's view some of the edges. Note that they are just 2-tuples of nodes.
print('Here are a few edges')
for edge in islice(G.edges().items(), 10):
    print(' -', edge)
# Out:
# Number of nodes: 6695
# Number of edges: 6461
# Here are a few nodes
#  - ((29, 3996), {'year': 2000})
#  - ((30, 3857), {'year': 2000})
#  - ((30, 1019), {'year': 2000})
#  - ((30, 1020), {'year': 2000})
#  - ((30, 1021), {'year': 2000})
#  - ((30, 1719), {'year': 2000})
#  - ((30, 803), {'year': 2000})
#  - ((30, 805), {'year': 2000})
#  - ((30, 806), {'year': 2000})
#  - ((30, 809), {'year': 2000})
# Here are a few edges
#  - ((29, 3996), {'year': 2000})
#  - ((30, 3857), {'year': 2000})
#  - ((30, 1019), {'year': 2000})
#  - ((30, 1020), {'year': 2000})
#  - ((30, 1021), {'year': 2000})
#  - ((30, 1719), {'year': 2000})
#  - ((30, 803), {'year': 2000})
#  - ((30, 805), {'year': 2000})
#  - ((30, 806), {'year': 2000})
#  - ((30, 809), {'year': 2000})

# %% [markdown]
# Citation system usually contains the following information:
# - Year of decision
# - Abbreviated title of the court
# - Decision number (not the court file number)

# %% [markdown]
# Let's use the **degree centrality** of the graph.

# %%
# Trim the graph
def trim_degrees(graph, degree=1):
    g = graph.copy()
    d=dict(nx.degree(g))
    for node in graph.nodes():
        if d[node] <= degree:
            g.remove_node(node)
    return g

print('Number of nodes:', trim_degrees(G).number_of_nodes())
# If we remove from the graph nodes with degree centrality less or equal than 1?
# From Number of nodes: 4789 to:
# Out:
# Number of nodes: 1427

# %% [markdown]
# Many of the citations are not referenced by other citations!

# %%
# What happen if we consider only the graph nodes with more than 25 degree centrality?
len(trim_degrees(G, degree=5))
# Out:
# 778

# %%
# Plot this new smaller graph
pos=nx.circular_layout(G)

nx.draw(trim_degrees(G, degree=25), pos)

# %% [markdown]
# ## Exploring the data
#
# If we want to explore the whole original network, let's make whatever observations we can about this example graph of case citations. As we saw above, simply printing a few nodes and edges is profoundly useless and tells us nothing about the data. Network data is challenging in that, even for small networks, there's really no easy way to understand the data without plotting it's characteristics and looking at some charts.

# %% [markdown]
# ### Plot Histograms
#
# Histograms might be helpful for the data. What vizualizations we need will depend on the data, but for purposes of basic exploration, we will probably want to look at some histograms.

# %%
# This histogram below shows the distribution of citing cases by publication years. 
# So we retrieved the publication year of the citing case for each network edge, 
# then plotted the distribution of those values.
from matplotlib import pyplot as plt
import numpy

years = tuple(G.get_edge_data(*edge)['year'] for edge in G.edges())
plt.hist(years, 14)
plt.xlabel('Years')
plt.ylabel('Number of Cases')
plt.show()

# %%
G.get_edge_data?

# %% [markdown]
# ### Degree Distribution of the Network
#
# If the network is scale-free, we may be able to apply network analysis techniques that are known to work well on other scale-free networks, like the Internet.

# %%
# Compute the degree histogram
degrees = dict(G.degree()).values() # degree returns a view object DegreeView
degree_hist = plt.hist(list(degrees), 100)
plt.xlabel('Number of cases with y inbound citations')
plt.ylabel('Number of inbound citations')
plt.show()

# %% [markdown]
# ### Page Rank
#
# Apply Page Rank to find the highest ranked source and print the sources that cite it:

# %%
from operator import itemgetter
 
# Calculating PageRank values for our graph
ranks = nx.pagerank(G)

# Let's retrieve the highest ranked case.
highest = sorted(ranks, key=ranks.get).pop()
first = itemgetter(0)
print('The highest ranked case was %s (%r)' % (highest, ranks[highest]))
print('It was cited by these cases:')
print(sorted(map(first, G.in_edges(highest))))
# Out:
# The highest ranked case was 3140 (0.0010008074934064258)
# It was cited by these cases:
# [353, 586, 788, 797, 1144, 1186, 1224, 1234, 1460, 1524, 1668, 1682, 1734, 1790, 1797, 1894, 1940, 2138, 2165, 2289, 2346, 2350, 2355, 2399, 2570, 2571, 2581, 2968, 2973, 3010, 3153, 3204, 3443, 3480, 4050, 4051, 4302, 4471, 4475, 4662]

# %% [markdown]
# 3. Twitter Network Analysis
# ===============================

# %% [markdown]
# <div class = "alert alert-success" style = "border-radius:10px;border-width:3px;border-color:darkgreen;font-family:Verdana,sans-serif;font-size:16px;">
# **Exercise**:
#
# </li>
# <ol>
# <ul>
# </ul>
# <li> Select a Twitter user and access to his/her followers doing scraping. Choose the user to have a reasonable number of nodes (a scientific, a football player,...). Stop at the second level of followers: access to main user followers and her/his followers F, add to the graph only the edges between the followers which are in F.</li>
#
# <li> Save the information using pickle for avoiding to repeat the scraping with the Twitter API.</li>
# <li> Build the graph.</li>
# <li> Use Page Rank to know who is the most connected person (highest ranked contact).</li>
# <li> Make a pruning of the graph by removing leaf nodes with degree less than a value passed to the parameter.</li>
# <li> Indicate which parameter setting is necessary to have a graph with less than 50 nodes.</li>
# <li> Look for a Hub node using centrality. </li>
# <li> Indicate the 10 users with:
# <ul>
#     <li> higher degree of centrality on the pruned graph</li>
#     <li> higher interrelation degree on the pruned graph</li>
#     <li> higher degree closeness centrality on the pruned graph</li>
#     <li> higher degree eigenvector centrality on the pruned graph</li>
# </ul>
# <li>  Find the maximal clique on the network and on the pruned network. Extract conclusions.</li>
#
# </ol>
# </div>

# %%
# Your solution here

# %% [markdown]
# 4. Facebook Network Analysis
# ===============================

# %% [markdown]
# <div class = "alert alert-success" style = "border-radius:10px;border-width:3px;border-color:darkgreen;font-family:Verdana,sans-serif;font-size:16px;">
# **Exercise**:
#
# </li>
# <ol>
# <ul>
# </ul>
# <li> We consider *Social circles: Facebook* [EGO_FACEBOOK](https://snap.stanford.edu/data/egonets-Facebook.html).
# This dataset consists of 'circles' (or 'friends lists') from Facebook. Facebook data was collected from survey participants using this Facebook app. The dataset includes node features (profiles), circles, and ego networks.
# Facebook data has been anonymized by replacing the Facebook-internal ids for each user with a new value. Also, while feature vectors from this dataset have been provided, the interpretation of those features has been obscured. For instance, where the original dataset may have contained a feature "political=Democratic Party", the new data would simply contain "political=anonymized feature 1". Thus, using the anonymized data it is possible to determine whether two users have the same political affiliations, but not what their individual political affiliations represent.</li>
#
# <li> Load the Facebook network into NetworkX!
# The ego-facebook dataset is defined by an edge list, so the file is a plain text file with one edge per line. The file is uncompressed and ready in `files/facebook_combined.txt`
# The network consists of an undirected and unweighted network that contains friendships between users of Facebook.</li>
# <li> Repeat the network analysis done with the Hamster network with this network.</li>
#
# <li> The Facebook network is divided into a set of 10 ego-networks which are interconnected to form the fully connected graph.
# The dataset includes the information of these 10 manually defined ego-networks. In particular, we have available the list of the 10 ego nodes: '0', '107', '348', '414', '686', '1684', '1912', '3437', '3980' and their connections.
# Extract the ego-networks of the node '107' with a distance of 1 and 2, and compute their sizes.</li>
#
#
# <li> Answer the following questions:
# <ul>
#     <li> Which is the most densely connected egonetwork?</li>
#     <li> Which is the largest (# nodes) egonetwork? </li>
#     <li> Is there intersection between ego-networks in the Facebook network?</li>
# </ul>
# </ol>
# </div>

# %%
# Load the facebook network:
facebook = nx.read_edgelist("files/facebook_combined.txt")

# %%
# Your solution here

# %%
# For point 4 use:
import os.path

egoid = '107'
G_107 = nx.read_edgelist(os.path.join('files/facebook','{0}.edges'.format(egoid)),nodetype=int)    
print('Nodes of the ego graph 107: ', len(G_107))
# Out:
# Nodes of the ego graph 107:  1034

# %%
# For questions in point 5 use

import numpy as np

# Fill the 'egosizes' vector with the size (number of edges) of the 10 egonetworks in egoids:
egoids=(0, 107, 348, 414, 686, 698, 1684, 1912, 3437, 3980)
egosizes=np.zeros((10,1))
i=0
for id in egoids :
    G = nx.read_edgelist(os.path.join('files/facebook','{0}.edges'.format(id)),nodetype=int)    
    egosizes[i]= G.size()      
    print('size of the egonetwork ', id,  egosizes[i])
    i +=1
# Out:
# size of the egonetwork  0 [ 2519.]
# size of the egonetwork  107 [ 26749.]
# size of the egonetwork  348 [ 3192.]
# size of the egonetwork  414 [ 1693.]
# size of the egonetwork  686 [ 1656.]
# size of the egonetwork  698 [ 270.]
# size of the egonetwork  1684 [ 14024.]
# size of the egonetwork  1912 [ 30025.]
# size of the egonetwork  3437 [ 4813.]
# size of the egonetwork  3980 [ 146.]
